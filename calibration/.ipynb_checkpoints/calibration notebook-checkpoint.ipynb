# %%
# %matplotlib notebook

import rosbag
import numpy as np
from std_msgs.msg import Int32, String
import matplotlib.pyplot as plt
from vicon_functions import *
import time
import least_square_circle
import math
import transforms3d as t3d
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# #  imports rosbag, quick import circle fit test

# %%
bag = rosbag.Bag('./bagfiles/2018-02-23-20-57-31.bag')
start = time.time()
output = parseViconPose(bag)
end = time.time()
print(end-start)
# Out:
# 6.45732712746

# %%
def PCA(data, correlation = False, sort = True):
    
    mean = np.mean(data, axis=0)

    data_adjust = data - mean

    #: the data is transposed due to np.cov/corrcoef syntax
    if correlation:

        matrix = np.corrcoef(data_adjust.T)

    else:
        matrix = np.cov(data_adjust.T) 

    eigenvalues, eigenvectors = np.linalg.eig(matrix)

    if sort:
        #: sort eigenvalues and eigenvectors
        sort = eigenvalues.argsort()[::-1]
        eigenvalues = eigenvalues[sort]
        eigenvectors = eigenvectors[:,sort]

    return eigenvalues, eigenvectors
""" Applies Principal Component Analysis to the data

Parameters
----------        
data: array
    The array containing the data. The array must have NxM dimensions, where each
    of the N rows represents a different individual record and each of the M columns
    represents a different variable recorded for that individual record.
        array([
        [V11, ... , V1m],
        ...,
        [Vn1, ... , Vnm]])

correlation(Optional) : bool
        Set the type of matrix to be computed (see Notes):
            If True compute the correlation matrix.
            If False(Default) compute the covariance matrix. 

sort(Optional) : bool
        Set the order that the eigenvalues/vectors will have
            If True(Default) they will be sorted (from higher value to less).
            If False they won't.   
Returns
-------
eigenvalues: (1,M) array
    The eigenvalues of the corresponding matrix.

eigenvector: (M,M) array
    The eigenvectors of the corresponding matrix.

Notes
-----
The correlation matrix is a better choice when there are different magnitudes
representing the M variables. Use covariance matrix in other cases.

"""



def best_fitting_plane(points, equation=False):
    w, v = PCA(points)

    #: the normal of the plane is the last eigenvector
    normal = v[:,2]

    #: get a point from the plane
    point = np.mean(points, axis=0)


    if equation:
        a, b, c = normal
        d = -(np.dot(normal, point))
        return a, b, c, d

    else:
        return point, normal    
""" Computes the best fitting plane of the given points

Parameters
----------        
points: array
    The x,y,z coordinates corresponding to the points from which we want
    to define the best fitting plane. Expected format:
        array([
        [x1,y1,z1],
        ...,
        [xn,yn,zn]])

equation(Optional) : bool
        Set the oputput plane format:
            If True return the a,b,c,d coefficients of the plane.
            If False(Default) return 1 Point and 1 Normal vector.    
Returns
-------
a, b, c, d : float
    The coefficients solving the plane equation.

or

point, normal: array
    The plane defined by 1 Point and 1 Normal vector. With format:
    array([Px,Py,Pz]), array([Nx,Ny,Nz])

"""
# Out:
# ' Computes the best fitting plane of the given points\n\nParameters\n----------        \npoints: array\n    The x,y,z coordinates corresponding to the points from which we want\n    to define the best fitting plane. Expected format:\n        array([\n        [x1,y1,z1],\n        ...,\n        [xn,yn,zn]])\n\nequation(Optional) : bool\n        Set the oputput plane format:\n            If True return the a,b,c,d coefficients of the plane.\n            If False(Default) return 1 Point and 1 Normal vector.    \nReturns\n-------\na, b, c, d : float\n    The coefficients solving the plane equation.\n\nor\n\npoint, normal: array\n    The plane defined by 1 Point and 1 Normal vector. With format:\n    array([Px,Py,Pz]), array([Nx,Ny,Nz])\n\n'

# %% [markdown]
# # fit plane and project points onto plane

# %%
xyz = output[6][:,:]
x = output[6][:,0]
y = output[6][:,1]
z = output[6][:,2]
q = output[7][:,:]

print('Variance in vicon coordinates: {}'.format(np.var(xyz, axis = 0)))
plt.figure()
plt.subplot(3,1,1)
plt.plot(x,y)
plt.subplot(3,1,2)
plt.plot(z,y)
plt.subplot(3,1,3)
plt.plot(z,x)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
Axes3D.scatter(ax, xyz[:,0], xyz[:,1], xyz[:,2])
plt.show()


point, normal = best_fitting_plane(xyz)
b = np.dot(normal, point) * normal

#component = (np.dot(normal, xyz.T))
#component = component[:,np.newaxis]

normal = normal[:, np.newaxis]
projection =  (np.dot(normal.T, xyz.T).T * normal.T)
pxyz = xyz - projection

fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d')
Axes3D.scatter(ax2, projection[:,0], projection[:,1], projection[:,2])
plt.show()

fig3 = plt.figure()
ax3 = fig3.add_subplot(111, projection='3d')
Axes3D.scatter(ax3, pxyz[:,0], pxyz[:,1], pxyz[:,2])
ax3.hold(True)

xvec = np.linspace(pxyz[:,0].min(), pxyz[:,0].max(), 100)
yvec = np.linspace(pxyz[:,1].min(), pxyz[:,1].max(), 100)
xx, yy = np.meshgrid(xvec, yvec)
z = (-normal[0] * xx - normal[1] * yy) * 1. / normal[2]
Axes3D.plot_surface(ax3, xx, yy, z)
                     
plt.show()
# Out:
# Variance in vicon coordinates: [5.75164289e-06 3.55542774e-04 3.75095280e-05]
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# # find points in their plane coordinate frame

# %%
v1 = normal.squeeze()
v2 = np.array([1,0,0])
v2 = v2 - (np.dot(v1,v2))*v1
v2 = v2 / np.linalg.norm(v2)
v2 = v2.squeeze()
v3 = np.array([0,1,0])
v3 = v3 - (np.dot(v2,v3))*v2 - (np.dot(v1,v3))*v1
v3 = v3 / np.linalg.norm(v3)
v3 = v3.squeeze()
if(np.linalg.norm(v3)<0.0001):
    v3 = np.array([0,0,1])
    v3 = v3 - (np.dot(v2,v3))*v2 - (np.dot(v1,v3))*v1
    v3 = v3 / np.linalg.norm(v3)
    v3 = v3.squeeze()

print(v1)
print(v2)
print(v3)
print(np.dot(v1,v2))
print(np.dot(v1,v3))
print(np.dot(v2,v3))

basis = np.array([v1,v2,v3]).squeeze().T
print(basis) #basis is composed of column vectors

# similiarity transform: http://mathworld.wolfram.com/SimilarityTransformation.html
xyz_in_frame = np.dot(basis.T, pxyz.T).T
yn = xyz_in_frame[:,1]
zn = xyz_in_frame[:,2]
print('Variance in plane coordinates: {}'.format(np.var(xyz_in_frame, axis = 0)))

plt.figure()
plt.plot(xyz_in_frame[:,1], xyz_in_frame[:,2])
plt.show()
# Out:
# [-0.97281211  0.02389459  0.23035983]
# [0.23159577 0.10036862 0.96762056]
# [-4.18567380e-17  9.94663354e-01 -1.03173695e-01]
# -3.885780586188048e-16
# 3.8163916471489756e-17
# -1.3877787807814457e-17
# [[-9.72812109e-01  2.31595771e-01 -4.18567380e-17]
#  [ 2.38945914e-02  1.00368620e-01  9.94663354e-01]
#  [ 2.30359826e-01  9.67620555e-01 -1.03173695e-01]]
# Variance in plane coordinates: [1.80274329e-33 6.65759727e-05 3.29923642e-04]
# <img src="data:image/png;base64,...">

# %%
#output[5] -= output[5][0,:]
#output[3] -= output[3][0,:]

plt.figure()
plt.plot(output[6][:,0])
plt.plot(output[6][:,1])
plt.plot(output[6][:,2])
plt.show()


plt.plot(output[6][:,1],output[6][:,2])



num_samples = len(q)

xc,yc,R,resid = least_square_circle.leastsq_circle(yn,zn)
print(resid)
least_square_circle.plot_data_circle(yn,zn, xc, yc, R)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# 0.0021457975333508505
# <img src="data:image/png;base64,...">

# %% [raw]
# plot orientations (sin) (cos)
# should form a circle

# %%
ax_angle = np.zeros((num_samples, 3))
for i in range(num_samples):
    ax_angle[i] = t3d.euler.quat2euler(q[i])

plt.plot(np.cos(ax_angle[:,0]), np.sin(ax_angle[:,0]))

# %% [markdown]
# # recenter points around (0,0) and replot

# %%
#prints sample points from orientation data
xt = np.array(x)
yt = np.array(y)
zt = np.array(z)

#prints number of samples
num_samples = len(x)
print(num_samples)


for i in range(num_samples):
    theta = (ax_angle[i,0])
    rmat = np.array([[np.cos(theta), -np.sin(theta)],[np.sin(theta), np.cos(theta)]])
    yz = np.array([y[i], z[i]])
    Rvec = np.array([R, 0])
    v = np.dot(rmat, Rvec)
    
    #yt[i] = y[i] - v[0]
    #zt[i] = z[i] - v[1]
    
    yt[i] = y[i] - R * np.sin(theta)
    zt[i] = z[i] - R * np.cos(theta)
    
least_square_circle.plot_data_circle(y,z, xc, yc, R)
plt.plot(yt,zt)
# Out:
# 13023

# %%
i = 0
theta = rx[i]
rmat = np.array([[np.cos(theta), -np.sin(theta)],[np.sin(theta), np.cos(theta)]])
yz = np.array([y[i], z[i]])
v = np.dot(rmat, yz)
v
# Out:
# array([0.23317155, 1.61197268])
